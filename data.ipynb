# %%
pip install google-api-python-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-api-python-client in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.127.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-python-client) (2.29.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-python-client) (2.18.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.23.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import googleapiclient.discovery

# %%
api_service_name = "youtube"
api_version = "v3"

# %%
api_key = 'AIzaSyDGyc89AGIBpCasY1HokFB4W7E5aOYFGhA'

# %%
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=api_key)

# %%
request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id="UCWphTVXhpV6RTcQffM_NbxQ"
)
response = request.execute()

# %%
def get_channel_data(channel_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id
    )
    response = request.execute()
    data = {
            "channel_name":response['items'][0]['snippet']['title'],
            "channel_des":response['items'][0]['snippet']['description'],
            "channel_p_id":response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
            "channel_pat":(response['items'][0]['snippet']['publishedAt']).replace("T"," ").replace("Z",""),
            "channel_sub_count":response['items'][0]['statistics']['subscriberCount'],
            "channel_vcount":response['items'][0]['statistics']['viewCount'],
            "channel_vid_count":response['items'][0]['statistics']['videoCount'],
            "channel_id":response['items'][0]['id']
    }
    return data

# %%
import isodate

# %%
import isodate
a = isodate.parse_duration("PT4M10S")
print(a)
# Out:
# 0:04:10

# %%
channel_info = get_channel_data('UCWphTVXhpV6RTcQffM_NbxQ')

# %%
get_channel_data("UCWphTVXhpV6RTcQffM_NbxQ")
# Out:
# {'channel_name': 'Engal Samayal எங்கள் சமையல்',
#  'channel_des': '"Traditional, healthy and tasty south tamilnadu cooking"',
#  'channel_p_id': 'UUWphTVXhpV6RTcQffM_NbxQ',
#  'channel_pat': '2019-03-06 08:32:53',
#  'channel_sub_count': '1150',
#  'channel_vcount': '132519',
#  'channel_vid_count': '218',
#  'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ'}

# %%
def get_video_ids(channel_id):
    video_ids = []

    request = youtube.channels().list(
                                     part = "contentDetails",
                                     id = channel_id 
    )
    response = request.execute()
    platlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token = None

    while True:
        response = youtube.playlistItems().list(
            playlistId = platlist_id,
            part = "snippet",
            maxResults = 50,
            pageToken = next_page_token
        ).execute()
        for i in range(len(response['items'])):
            video_ids.append(response['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token = response.get('nextPageToken')
        if next_page_token is None:
            break
    return video_ids

# %%
request = youtube.channels().list(
                                     part = "contentDetails",
                                     id = "UCWphTVXhpV6RTcQffM_NbxQ" )
response = request.execute()

# %%
response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
# Out:
# 'UUWphTVXhpV6RTcQffM_NbxQ'

# %%
video_Ids = get_video_ids(channel_id='UCWphTVXhpV6RTcQffM_NbxQ')

# %%
video_Ids
# Out:
# ['mpz317KgF68',
#  'qulj2SaVpZc',
#  'v-DkWH2dbYI',
#  'BQrahU9HjQY',
#  'mt6Z-ULhPGo',
#  '3egvhKLJMrQ',
#  'i_uMa2LMBe8',
#  'mv_d2ppkCqs',
#  'taVaHGtPs68',
#  'EzWIbWBMQhE',
#  'GSnD6LKmss0',
#  'iuPCQ0ERTGM',
#  '18qsCLIu-p0',
#  'vxOw3zKKXhQ',
#  '9ZARh4gt89M',
#  'bNnf3mwhnzM',
#  'ktPOChMxMrg',
#  'tDFkEkyZmqU',
#  'GXDGyjsWy7M',
#  '52Ovmw-m-oM',
#  'LK3_JqLNS0c',
#  'CA_u8qOp0yA',
#  'MAZ1TamaLgg',
#  'agQ8yVt1l-s',
#  'x8fsitvTio8',
#  'rPNOmZH5Woo',
#  '67L9o8PHs1s',
#  'KCdknlnGZUI',
#  'lhMeGbbcTV8',
#  'c8m-mRvLWQk',
#  'yuUYmuENt-c',
#  'MVeGlP6mlvA',
#  'T0rhZpEa9ck',
#  'Z9DUFTZvFRI',
#  '8pSsZssK-BM',
#  'RATo_-1X93k',
#  '61JIMdx-B9g',
#  'ZiRCHnwhWbY',
#  'ZDQO_zsVyH0',
#  '8ZLMt_dCQyo',
#  'GJKLWNQpQBo',
#  'pZ_37DzZqks',
#  'HMASM8ulax8',
#  'fCisjaYyOWY',
#  '8Oi5hxCSMxc',
#  'Tn16dYwwsd8',
#  'ieJwevFOdaE',
#  'EK8AUZx6N3c',
#  'M4jT2Xk4ZY0',
#  '8GaNCABuQoU',
#  'n6bc2bLw0iM',
#  'Ao9d6IGVA-Q',
#  'I3Q_CSvPRdY',
#  'YNWTW1fyA_4',
#  'jsPL_WT1MeI',
#  'ITXAqfx-8sk',
#  'LEf-zDnVLCs',
#  'zR3bG3w9X4U',
#  'yz1QKWEPxh0',
#  '5qFH8EhZWs8',
#  'LqQHPHUqxYo',
#  'M6SShIbnh1M',
#  'r7SUSXuYkAQ',
#  'J0XYpHWtinY',
#  'bZPtWstZn3c',
#  'l1EGiQBwDXA',
#  'XS78cAmya2s',
#  'TsgN7ZtxcXs',
#  'NrgjhKZkcTg',
#  'xTNyf9o1aGo',
#  '9H2z9b09Qvc',
#  'xe08KDkvA7Q',
#  'zcKkBGkGM5E',
#  'njfl-kAEEIs',
#  'winrGyyJiuI',
#  'c51tZWvjy2o',
#  '2f7gCHnOU-w',
#  '6bAvCOyMwy4',
#  'NSfcibnYwhQ',
#  'op02wAT2CmI',
#  '7kTEmqdFIw8',
#  'hazWdCwwX8w',
#  '-hZ1Clq0yq4',
#  'GE1FwBSFE5o',
#  'gdOztN2lp10',
#  'yhkd8cu6M-8',
#  '2DP75REMDWg',
#  'Prphlo-O3gY',
#  'hVzMS78CfW4',
#  'mzk6lymQrh0',
#  'VKYMzJAs3Hk',
#  'Qzxxd3lTOZ4',
#  '3ar4PGd8C5s',
#  '0EqJMao3928',
#  'SSVy6NhOYj4',
#  '_2Amv71kFfw',
#  'lsmYi24iPqU',
#  'wggF7ftzWbc',
#  'JryflLFUxmY',
#  'bQBOT1Zai2E',
#  '_yDd2t44ba8',
#  'MbA4bc0__OQ',
#  'F0QfjkNk4sY',
#  'Vz177tgFHTk',
#  'dJ6Nix8-Hfk',
#  'yxLzOAZtocg',
#  'YOB1H_36yKU',
#  'LfktAsmpwpA',
#  'Zy8SWBkoi24',
#  'w8IccErh7AE',
#  'M5r3sVHtyHc',
#  'd_qt28TfoyM',
#  'jHgsPIWlU_U',
#  'rtGNYAecS_8',
#  'hUkDrRdRr1I',
#  'VWCZIpiLCME',
#  'hURpTrZa0qI',
#  'fwRORr3C8-c',
#  'H_YfMx4Sh44',
#  'QsDsGLkFm0k',
#  'Ug5nc-iIW4E',
#  'VBNL_67AnFg',
#  'xqcOugXDrcM',
#  'lDh14FYp3bo',
#  'yJN8-bD90JI',
#  'giSpelOnZuQ',
#  '3Yh-wF9A5hE',
#  'VF7UG0yYcEU',
#  'jK0IPwYRpDw',
#  'gwn5vcNHUqQ',
#  'aerFoGzsWr4',
#  'uYKlzUQszLA',
#  'muxiBIMJ0Aw',
#  '7tMnOWN4mas',
#  '8Td2apVsdPQ',
#  '3W-6l2W_KDA',
#  '2Iqp06MdjHk',
#  'hh9YaxsHu1k',
#  'wghrWKnFz7A',
#  'KLg1juMUlvI',
#  'A3gtDg98DY8',
#  'Pk6JYl9dvo0',
#  'de_A2tMDX60',
#  '5DfGjgKtBgY',
#  'p-8cvw5tRR0',
#  'bTi2kfksERU',
#  'v4mBf8YBMmU',
#  'rRZo0-04e4I',
#  'Ej9usL-ES6g',
#  'f7W5uLIKeiY',
#  'GIA7u8p6KCU',
#  'h9Ha0x9Pdmk',
#  'GKxgzQKanoQ',
#  'Uylu5AqqeFs',
#  '3_s9cqGez6Y',
#  'n52T1VtyoI4',
#  'tvxEzuEIov0',
#  'vVa8gLhxxL0',
#  'tJhV0OADulk',
#  'X9fY8taYKFE',
#  'GLi99ITRr3E',
#  'YYt1CAHcD7I',
#  'EAS6b10VBRA',
#  'URSodY6Y9x4',
#  'FeWeJnmlHmA',
#  'p4aa51HLDGc',
#  'DhYVQjdpSqk',
#  '5xEQXaUbqTw',
#  'cA3ajw-ROCg',
#  'PvWGOfFr1zg',
#  'iYLn87baeOo',
#  'duhl5KFfwC4',
#  'MDiDR6mp5fc',
#  '28HPXnCSbjU',
#  'EzK4yTFSI8w',
#  'RvF62z-ss70',
#  'QRumCtai6ng',
#  '5HiM9YFNbmc',
#  'eejAKmEmOIw',
#  'HMGM3o-zZ6A',
#  'y16wgj8sp8o',
#  'BIJmdDHTcOg',
#  'Ko-8AjK9YgA',
#  'Otzu8Lm4RC0',
#  'VQUaNfRKjEU',
#  'NIEsJx-FCaQ',
#  'yYTs7Z8kTGI',
#  '7VueVoRWeoo',
#  'USROD5ZQ4iU',
#  'eleckDLGOp4',
#  'dZHL4iB_xaQ',
#  '0sHYgMptS4M',
#  'IFxQ0rpeloE',
#  'Z7mBra9vqeE',
#  'sgXeFLrg6eY',
#  'lorFKWJXUf0',
#  'FSU-2If91iw',
#  'E5CDjLiCO28',
#  '22349qOwAWI',
#  '52eQXW_RdWI',
#  'lBkh6I4JtOk',
#  'ZtCXPZXzV-4',
#  'OL7ILd9K1-o',
#  'jzOEeVexkwE',
#  '-_q-gt_2ft0',
#  'hSzYja_UPpg',
#  'aAyUr7dm-og',
#  'cXS8KFxkkgY',
#  '54jCeLqiPJo',
#  'tdMWoeTFIkI',
#  'y7Lzfc6b_T4',
#  'rcVY7E_lKhQ',
#  'kAFSwXETQ6k',
#  'Bv_9anv4bF4',
#  '-EkWdAZru7g',
#  'aV4_sxh3pa8',
#  't7GJ22GHqQs',
#  'gzP50pRyjIY',
#  'CVIBrcaurS4',
#  'nSdTnRo--Z8']

# %%
def get_video_data(video_Ids):
    video_data = []
    for video_id in video_Ids:
        request = youtube.videos().list(
                                    part="snippet,contentDetails,statistics",
                                    id=video_id
                                    )
        response1 = request.execute()
        data1 = {"channel_id":response1['items'][0]['snippet']['channelId'],
                "channel_name":response1['items'][0]['snippet']['channelTitle'],
                "video_id":response1['items'][0]['id'],
                "video_title":response1['items'][0]['snippet']['title'],
                "video_pat":response1['items'][0]['snippet']['publishedAt'],
                "video_des":response1['items'][0]['snippet'].get('description'),
                "video_tags":response1['items'][0].get('tags'),
                "video_captionstatus":response1['items'][0]['contentDetails']['caption'],
                "video_def":response1['items'][0]['contentDetails']['definition'],
                "video_duration":isodate.parse_duration(response1['items'][0]['contentDetails']['duration']),
                "video_lc":response1['items'][0]['statistics'].get('likeCount'),
                "video_vc":response1['items'][0]['statistics']['viewCount'],
                "video_cc":response1['items'][0]['statistics'].get('commentCount'),
                "video_fc":response1['items'][0]['statistics']['favoriteCount']

            }
        video_data.append(data1)

    return video_data

# %%
request = youtube.videos().list(
                                    part="snippet,contentDetails,statistics",
                                    id="mpz317KgF68"
                                    )
response1 = request.execute()
data1 = {"channel_id":response1['items'][0]['snippet']['channelId'],
                "channel_name":response1['items'][0]['snippet']['channelTitle'],
                "video_id":response1['items'][0]['id'],
                "video_title":response1['items'][0]['snippet']['title'],
                "video_pat":response1['items'][0]['snippet']['publishedAt'],
                "video_des":response1['items'][0]['snippet'].get('description'),
                "video_tags":response1['items'][0].get('tags'),
                "video_captionstatus":response1['items'][0]['contentDetails']['caption'],
                "video_def":response1['items'][0]['contentDetails']['definition'],
                "video_duration":str(isodate.parse_duration(response1['items'][0]['contentDetails']['duration'])),
                "video_lc":response1['items'][0]['statistics'].get('likeCount'),
                "video_vc":response1['items'][0]['statistics']['viewCount'],
                "video_cc":response1['items'][0]['statistics'].get('commentCount'),
                "video_fc":response1['items'][0]['statistics']['favoriteCount']

            }

# %%
request = youtube.videos().list(
                                    part="snippet,contentDetails,statistics",
                                    id="mpz317KgF68"
                                    )
response1 = request.execute()

# %%
response1['items'][0]['statistics'].get('likeCount')
# Out:
# '17'

# %%
response1['items'][0]['snippet']['']
# Out:
# '17'

# %%
import re
from datetime import datetime 

def convert_duration(duration):
    regex = r'PT(\d+H)?(\d+M)?(\d+S)?'
    match = re.match(regex, duration)
    if not match:
        return '00:00:00'

    hours, minutes, seconds = match.groups()
    hours = int(hours[:-1]) if hours else 0
    minutes = int(minutes[:-1]) if minutes else 0
    seconds = int(seconds[:-1]) if seconds else 0

    total_seconds = hours * 3600 + minutes * 60 + seconds
    return total_seconds

# %%
video_info=get_video_data(video_Ids)

# %%
video_info
# Out:
# [{'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'mpz317KgF68',
#   'video_title': 'பால் மட்டும் போதும் இரண்டு ஸ்வீட் செஞ்சிடலாம்',
#   'video_pat': '2020-09-25T08:00:43Z',
#   'video_des': 'How to make sweets for this diwali\nhomemade sweets',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 250,
#   'video_lc': '17',
#   'video_vc': '256',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'qulj2SaVpZc',
#   'video_title': 'உங்க பசங்களுக்கு இந்த dish a செஞ்சிகுடுங்க | Kids Favorite dish...',
#   'video_pat': '2020-09-20T08:57:38Z',
#   'video_des': 'chocolate recipe\n\nchocolate custard pudding',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 201,
#   'video_lc': '21',
#   'video_vc': '189',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'v-DkWH2dbYI',
#   'video_title': 'For Construction, Interiors,2D plan,3D Elevation  , Contact Elegent Designers and Builders',
#   'video_pat': '2020-09-19T09:21:16Z',
#   'video_des': 'At K.T.C nagar, Tirunelveli\n\n\nFacebook page\n\nhttps://www.facebook.com/elegantbuildersofficial/',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 32,
#   'video_lc': '11',
#   'video_vc': '137',
#   'video_cc': '1',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'BQrahU9HjQY',
#   'video_title': 'Homemade Sambar powder',
#   'video_pat': '2020-09-18T03:56:54Z',
#   'video_des': 'Homemade Sambar powder. we can make Sambar powder in home with these steps easily.',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 170,
#   'video_lc': '13',
#   'video_vc': '136',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'mt6Z-ULhPGo',
#   'video_title': 'காரமா சாப்பிடுறவங்க கண்டிப்பா இந்த dish a  செஞ்சி பாருங்க. |கார சாரமான சிக்கன் சுக்கா',
#   'video_pat': '2020-09-15T05:01:51Z',
#   'video_des': 'Hyderabad chicken sukka...\n\nசமைக்கும் போது masala வறுத்து அரைத்து சேர்த்தால் செம டேஸ்ட்....\nசிக்கன் சுக்கா இப்படி செஞ்சி பாருங்க\nchicken sukka\nkaara saaramana chicken sukka\nchicken recipes\nchicken sukka in tamil\n Hyderabad chicken sukka',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 183,
#   'video_lc': '16',
#   'video_vc': '136',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '3egvhKLJMrQ',
#   'video_title': 'Kerala style MEEN POLICHATHU in banana leaf | மீன் பொழிச்சது in tamil',
#   'video_pat': '2020-09-12T11:19:29Z',
#   'video_des': 'Kerala style fish recipe. Kerala special MEEN POLICHATHU in banana leaf. MEEN POLICHATHU is a fish recipe which is very famous in kerala state.',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 218,
#   'video_lc': '22',
#   'video_vc': '227',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'i_uMa2LMBe8',
#   'video_title': 'பாரம்பரிய மருந்து சோறு | மீன் வறுவல் | உள்ளூர் சமையல்',
#   'video_pat': '2020-09-10T07:02:36Z',
#   'video_des': 'ஆரோக்கியமான உணவு\nஎங்க ஊர் சமையல் மருந்து சோறு, மீன் குழம்பு,வஞ்சரம் மீன் வறுவல்\nHealthy rice and vanjaram fish fry\n\nif you want to purchase this marudhu powder,please comment in comment section and we will get back to you...',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 242,
#   'video_lc': '15',
#   'video_vc': '221',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'mv_d2ppkCqs',
#   'video_title': 'உளுந்த வடை செஞ்சீங்கன்னா கண்டிப்பா இதையும் செஞ்சு பாருங்க | Restaurant style curd vada',
#   'video_pat': '2020-09-08T08:48:06Z',
#   'video_des': 'All time recipe..',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 110,
#   'video_lc': '18',
#   'video_vc': '180',
#   'video_cc': '10',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'taVaHGtPs68',
#   'video_title': 'Low calorie chicken biriyani 😋',
#   'video_pat': '2020-09-07T06:27:46Z',
#   'video_des': 'Love biriyani but hesitate to eat biriyani because of high calorie?? In this video we shows how to cook low carbs chicken biriyani.',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 189,
#   'video_lc': '21',
#   'video_vc': '141',
#   'video_cc': '10',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'EzWIbWBMQhE',
#   'video_title': '4 விதமான ஊத்தப்பம் ஒரே நேரத்தில் | 4 types of Uttappam at the same time',
#   'video_pat': '2020-09-03T05:50:49Z',
#   'video_des': 'Types of dosa...\nhow to make different types of dosai\nhow to make different types of uttappam at the same time\n\nvegetables uttappam \negg uttappam\npanneer uttappam\nkari uttappam',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 213,
#   'video_lc': '14',
#   'video_vc': '104',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'GSnD6LKmss0',
#   'video_title': 'உள்ளி பால் தெரியுமா ??',
#   'video_pat': '2020-09-01T08:00:04Z',
#   'video_des': 'Tasty drink prepared using garlic, ginger, coconut milk, egg and jaggery. This tasty and healthy drink is good for women after pregnancy.\n\nIngredients \n\nJaggery - 300g\nGarlic - 300g\nGinger - 50g\nCoconut - 1/2\nEggs - 2\nGhee - 2tbspn\nGingelly oil - 4tbspn\nMaintain these measurements for perfect garlic milk\n\nHealth Benefits of Garlic Milk\n\n\nTreats & Prevents Acne\n\nPrevents Constipation & Bloating\n\nReduces the Risk of the Common Cold & Flu\n\nHelps to Treat Erectile Dysfunction\n\nActs as a Natural Aphrodisiac\n\nProtects the Heart\n\nAids Diabetes Control\n\nCould Lower Cancer Risk',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 233,
#   'video_lc': '35',
#   'video_vc': '413',
#   'video_cc': '16',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'iuPCQ0ERTGM',
#   'video_title': 'ஆரோக்கியமான காலை உணவு | Healthy Breakfast recipe |கோதுமை ரவை கிச்சடி',
#   'video_pat': '2020-08-29T11:06:03Z',
#   'video_des': 'Diet morning recipe\nVegetable samba/wheat rava kitchadi\nHealthy breakfast / dinner recipes\n#stayhealthy\n#staysafe\n#dietrecipe\n#healthyrecipe\n\nIngredients\nwheat raja..1 cup\nwater..2.5 cups\ncarrot\nbeans\npeas\ngreen chillies...3\nonion..2\ntomato...1\nginger garlic paste...1 spoon\ncinnamon,gloves, cardamom\nfennel seeds..1 spoon\nchilli powder..1/2spoon\nturmeric powder...1/4spoon\n\ndiet recipes\nhealthy recipes\nbreakfast recipes\ndinner recipes\nhealthy breakfast/dinner recipes for sugar patients',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 193,
#   'video_lc': '21',
#   'video_vc': '215',
#   'video_cc': '1',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '18qsCLIu-p0',
#   'video_title': 'முஹர்ரம் ஸ்பெஷல் கொழுக்கட்டை | Muharram special kozhukkattai',
#   'video_pat': '2020-08-28T10:30:38Z',
#   'video_des': 'Muharram special traditional kozhukkattai. கருப்பட்டி கொழுக்கட்டை.\n\nmuharam special\naasura special recipe kozhukkattai\nmuharam 10\nathar batcha kolakkattai\nmadak\nsweet kozhukkattai\nkaruppatti sweet\n\nIngredients :\n\nputtu Flour\nmoong dal\nkaruppatti /palm jaggery\ngratted coconut\n\n\n\nclick the below link for How to prepare Puttu flour \n\nhttps://youtu.be/OL7ILd9K1-o\n\nAnother type of sweet kozhukkattai... madak kolakkattai\n\nhttps://youtu.be/22349qOwAWI\n\nTraditional kakkadi video..\n\nhttps://youtu.be/52eQXW_RdWI\n\nkaara kolakkattai video link\n\nhttps://youtu.be/FSU-2If91iw',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 188,
#   'video_lc': '24',
#   'video_vc': '365',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'vxOw3zKKXhQ',
#   'video_title': 'Arabian Sweet | Umm Ali | Egyptian Bread Sweet in tamil',
#   'video_pat': '2020-08-26T01:01:57Z',
#   'video_des': 'How  to make egyptian sweet umm ali in tamil\n\nBread sweet\nShahi thukkada\nArabian Shahi thukkada\nInternational recipe\n\n கடல் கடந்து போகாம் வாங்க\nஉம் அலி\n\nIngredients\nBread.. 10\nMilk..3 cup...750 ml\nMilk Powder... half cup\nsugar...3 spoon\ncorn flour..3 spoon\n\nsugar syrup ... 1cup water,half cup sugar\n\nNuts... badam,pista, cashew, rasins,saffron (optional)',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 222,
#   'video_lc': '23',
#   'video_vc': '203',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '9ZARh4gt89M',
#   'video_title': 'Caramel bread popcorn | Only 3 ingredients simple and delicious sweet popcorn |snacks and bakes',
#   'video_pat': '2020-08-24T08:42:41Z',
#   'video_des': "How to make caramel bread popcorn. Some tips to make perfect caramel. This caramel bread popcorn is very easy to make. \nInspired by Nino's Home.",
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 181,
#   'video_lc': '21',
#   'video_vc': '139',
#   'video_cc': '8',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'bNnf3mwhnzM',
#   'video_title': 'வெயிலில் காயவைக்காமல் இரண்டு விதமான அப்பளம்/வடகம் செய்வது எப்படி',
#   'video_pat': '2020-08-22T05:23:31Z',
#   'video_des': 'How to make two types of appalam / vadakam without drying under the sun\n\n\nRice vadakam\npappad making\nappalam seivadhu eppadi \nvadakam making\nrice vadaham\nrice appalam\n\nIngredients\n\nRaw rice... 400 gm\ngreen chilli..3\ncumin seeds..1/2 spoon \nhing... small piece\n\nred chilli... 5\ncumin seeds...1/2spoon\nhing...small piece\nsalt',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 231,
#   'video_lc': '19',
#   'video_vc': '190',
#   'video_cc': '8',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'ktPOChMxMrg',
#   'video_title': 'Engal Samayal எங்கள் சமையல் Live Stream',
#   'video_pat': '2020-08-19T10:09:34Z',
#   'video_des': '',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': '00:00:00',
#   'video_lc': '0',
#   'video_vc': '0',
#   'video_cc': '0',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'tDFkEkyZmqU',
#   'video_title': 'Healthy veg menu for lunch | வாழைப்பூ  சாம்பார், உருளை வறுவல், சிறுகீரை பொரியல்',
#   'video_pat': '2020-08-19T07:23:20Z',
#   'video_des': 'Full veg menu for lunch. Worry about what to cook today? Watch this video you will get an idea.\n\nஆரோக்கிய மதிய உணவு | வாழைப்பூ  சாம்பார், உருளை வறுவல், சிறுகீரை பொரியல்',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 232,
#   'video_lc': '30',
#   'video_vc': '199',
#   'video_cc': '13',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'GXDGyjsWy7M',
#   'video_title': 'சிக்கன் குழம்பு ஒருமுறை இப்படி செய்து பாருங்கள்| சுவையான சிக்கன் குழம்பு |உள்ளூர் சமையல்',
#   'video_pat': '2020-08-16T09:49:03Z',
#   'video_des': '#Chickengravy\n#Chickenkulambu\n#chickenrecipe\nLike,comment and share\n\nIngredients...\nCoriander seed..3 spoon\nCumin...1 spoon\nPepper corn...1 spoon\nFennel seeds...1 spoon\nRed chilli...5\nCoconut...1 big piece\nOnion...1\nTomato...1\nGinger garlic paste..1 spoon\nGreen chilli..1\nCurry leaves..\nChicken\nSalt',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 156,
#   'video_lc': '21',
#   'video_vc': '187',
#   'video_cc': '12',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '52Ovmw-m-oM',
#   'video_title': 'Meat balls | Meat Kolaurundai | கறி கோலாஉருண்டை |  உள்ளூர் சமையல்',
#   'video_pat': '2020-08-14T12:53:31Z',
#   'video_des': 'Kolaurundai\n\nBeef Provides a Large Source of L-Carnitine. \nBeef Provides the “Master Antioxidant” Glutathione.\nBeef is High in Protein and Helps Improve Muscle Mass.\nBeef is Extremely Rich in Minerals.\nEating Beef Helps Prevent Iron Deficiency Anemia. \nBeef Contains Carnosine, a Potent Amino Acid. .\nBeef is Full of Vitamins.\n\nHere in this video lets see how to make beef chukka in a simple and easy way.\n\nClick this link for mutton chukka\n\nhttps://youtu.be/v4mBf8YBMmU',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 125,
#   'video_lc': '20',
#   'video_vc': '141',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'LK3_JqLNS0c',
#   'video_title': 'Marshmallow recipe | How to make marshmallow at home',
#   'video_pat': '2020-08-11T05:44:30Z',
#   'video_des': 'Homemade marshmallow. Marshmallow is a type of confectionery. Marshmallow tastes like jujubi.',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 305,
#   'video_lc': '35',
#   'video_vc': '238',
#   'video_cc': '17',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'CA_u8qOp0yA',
#   'video_title': 'Simple and tasty beef sukka...| உள்ளூர் சமையல்',
#   'video_pat': '2020-08-08T10:16:02Z',
#   'video_des': 'Beef Provides a Large Source of L-Carnitine. \nBeef Provides the “Master Antioxidant” Glutathione.\nBeef is High in Protein and Helps Improve Muscle Mass.\nBeef is Extremely Rich in Minerals.\nEating Beef Helps Prevent Iron Deficiency Anemia. \nBeef Contains Carnosine, a Potent Amino Acid. .\nBeef is Full of Vitamins.\n\nHere in this video lets see how to make beef chukka in a simple and easy way.\n\nClick this link for mutton chukka\n\nhttps://youtu.be/v4mBf8YBMmU',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 121,
#   'video_lc': '21',
#   'video_vc': '206',
#   'video_cc': '11',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'MAZ1TamaLgg',
#   'video_title': '2 types of Evening Snacks with bread',
#   'video_pat': '2020-08-06T08:58:47Z',
#   'video_des': '2 different types of Bread sandwichs\n\n\n#eveningsnacks\n#breadrrecipes\n#sandwich\n\negg less mayonnaise:\n\nhttps://youtu.be/hUkDrRdRr1I\n\nevening snacks ready\n\nhow to make garlic cheese bread\nhow to make egg mayo sandwich\negg recipe\nsnacks with egg\nsnacks with bread',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 193,
#   'video_lc': '23',
#   'video_vc': '212',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'agQ8yVt1l-s',
#   'video_title': '4 Types of easy homemade sweets | bakrid | Eid special sweets',
#   'video_pat': '2020-07-31T12:29:31Z',
#   'video_des': '4 types of homemade sweets \nIt is easy for us to make and also tasty \nGulab jamun\nPinnaple jam\nBread jam\nBeetroot halwa\n\nTraditional sweets\nhttps://youtu.be/M4jT2Xk4ZY0',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 331,
#   'video_lc': '15',
#   'video_vc': '225',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'x8fsitvTio8',
#   'video_title': 'எங்க வீட்டு சிக்கன் பிரியாணி | Bakrid special Chicken biriyani',
#   'video_pat': '2020-07-30T11:34:41Z',
#   'video_des': 'How to make dum chicken biriyani',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 284,
#   'video_lc': '15',
#   'video_vc': '152',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'rPNOmZH5Woo',
#   'video_title': 'Restaurant style Special Chicken Fry | Bakrid Special | Easy and yummy Chicken fry',
#   'video_pat': '2020-07-29T08:00:30Z',
#   'video_des': 'Restaurant style chicken fry. This chicken fry will be a perfect side dish for biriyani. This chicken fry is very easy to make.\n\nClick this link for more recipes of chicken fry\nhttps://youtu.be/tJhV0OADulk\nhttps://youtu.be/tvxEzuEIov0\nhttps://youtu.be/n52T1VtyoI4\n\n\n State uttu state\n#eidspecial\n#stayhomestaysafe',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 134,
#   'video_lc': '22',
#   'video_vc': '124',
#   'video_cc': '12',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '67L9o8PHs1s',
#   'video_title': 'Grill chicken | Full chicken grill in oven',
#   'video_pat': '2020-07-27T06:12:46Z',
#   'video_des': 'In this video we shows how to make full chicken grill at home. It tastes like restaurant style full chicken grill. Grill chicken is very easy to make\n\nClick this link for chicken seekh kebab\nhttps://youtu.be/JryflLFUxmY\n\n#chickenrecipes #grillchicken #fullchickengrill',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 223,
#   'video_lc': '23',
#   'video_vc': '135',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'KCdknlnGZUI',
#   'video_title': 'Brownies at home |Wheat Chocolate brownies at home | snacks and bakes| Best Homemade Brownies',
#   'video_pat': '2020-07-24T12:29:01Z',
#   'video_des': 'In this video we shows how to make wheat brownie at home. Brownie is a famous American snack. Brownies are very delicious and it is very easy to make at home.\n\nClick this link for dalgona cake\nhttps://youtu.be/NSfcibnYwhQ\n\nIngredients for brownie\n\nDark Chocolate...160gm\nButter...110gm\nSugar...200 gm\nEggs...3\nvanilla essence..1spoon\nWheat Flour...130 gm\ncoco powder...3 spoon\nsalt...1/4 spoon\n\nwheat brownie\nbrownie fudge\nchocolate brownie\nbrownies\nbrownie with vanilla ice cream',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 272,
#   'video_lc': '28',
#   'video_vc': '153',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'lhMeGbbcTV8',
#   'video_title': 'Easy Evening snacks... இதை சுட்டு வைத்தால் தட்டில் எல்லாம் காலியாகிடும்.|Snacks and Bakes',
#   'video_pat': '2020-07-21T08:11:39Z',
#   'video_des': '#lockdowneasysnacks\n#lockdownrecipes\n#easysnacks\nEvening easy sweet snacks ready',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 145,
#   'video_lc': '10',
#   'video_vc': '124',
#   'video_cc': '0',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'c8m-mRvLWQk',
#   'video_title': 'இட்லி பொடி & பொடி தோசை | Idly podi & podi dosa',
#   'video_pat': '2020-07-16T08:25:49Z',
#   'video_des': 'How to make idly podi in home',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 213,
#   'video_lc': '12',
#   'video_vc': '102',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'yuUYmuENt-c',
#   'video_title': 'Vlog | My first day out after lockdown',
#   'video_pat': '2020-07-14T07:15:43Z',
#   'video_des': 'Outing after lockdown\n#stayhomestaysafe\n#lockdown',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 250,
#   'video_lc': '18',
#   'video_vc': '207',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'MVeGlP6mlvA',
#   'video_title': 'வாழைப்பழம் இருந்தா அல்வா செஞ்சி பாருங்க ,சூப்பரா இருக்கும் | snacks and bakes |banana halwa',
#   'video_pat': '2020-07-12T09:07:20Z',
#   'video_des': '#stayhomestaysafe\n#lockdownrecipes\n#lockdownsnacks\n#halwa\nHow to make banana halwa in 30 minuties ...\n\nIngredients..\n\nbanana..4\ncorn flour...3 spoon\nghee...7 spoon\ncashew...5',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 168,
#   'video_lc': '20',
#   'video_vc': '118',
#   'video_cc': '8',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'T0rhZpEa9ck',
#   'video_title': 'Arabic sweet balls | Arabic sweet dumplings Luqaimat | How to make Arabic dumplings in tamil',
#   'video_pat': '2020-07-10T04:09:54Z',
#   'video_des': "Arabic traditional sweet dumplings. This Arabic sweet Luqaimat is very famous among Arabs. Arabic sweet dumplings is a Simple recipe just try you'll love it.\n\nClick this link for Arabic sweet kunafa\nhttps://youtu.be/ITXAqfx-8sk",
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 194,
#   'video_lc': '21',
#   'video_vc': '323',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'Z9DUFTZvFRI',
#   'video_title': 'மீன் குழம்புக்கு பதில் மீன் கூட்டு செஞ்சி பாருங்க...| உள்ளூர் சமையல் | Fish Curry',
#   'video_pat': '2020-07-08T10:12:31Z',
#   'video_des': 'Fish koottu\n#stayhomestaysafe\n#lockdownrecipe\n#fishgravy\n#fishrecipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 155,
#   'video_lc': '20',
#   'video_vc': '155',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '8pSsZssK-BM',
#   'video_title': 'State uttu state | Yummy tasty chicken curry',
#   'video_pat': '2020-07-06T03:15:02Z',
#   'video_des': 'Tasty chicken curry\nIngredients for marinating\nChicken\nSalt\nChilly powder\nTurmeric powder\nLemon\nIngredients for gravy\nOil\nOnion\nGinger garlic paste\nCurry leaves\nCoriander powder\nChilly powder\nGaram masala powder\nCoriander leaves',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 170,
#   'video_lc': '14',
#   'video_vc': '104',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'RATo_-1X93k',
#   'video_title': 'Different aana Bread sandwich | paneer  burji cheese bread sandwich',
#   'video_pat': '2020-07-03T06:32:49Z',
#   'video_des': 'State uttu state...\n#lockdownrecipe\n#breadrecipe\n#sandwich\n#panneer',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 182,
#   'video_lc': '18',
#   'video_vc': '113',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '61JIMdx-B9g',
#   'video_title': 'உள்ளூர் சமையல் | மட்டன் எடுத்தா இந்த மாதிரி செஞ்சு பாருங்க | South India mutton gravy',
#   'video_pat': '2020-06-29T07:18:05Z',
#   'video_des': 'Southside tasty mutton gravy recipe',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 192,
#   'video_lc': '20',
#   'video_vc': '154',
#   'video_cc': '12',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'ZiRCHnwhWbY',
#   'video_title': 'உள்ளூர் சமையல் | எல்லாம் கலந்த சுவை',
#   'video_pat': '2020-06-27T07:05:10Z',
#   'video_des': 'Mango season recipe',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 151,
#   'video_lc': '16',
#   'video_vc': '151',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'ZDQO_zsVyH0',
#   'video_title': 'Snacks and Bakes..| Mango malai cake',
#   'video_pat': '2020-06-25T07:21:04Z',
#   'video_des': 'Different type of cake with malai',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 257,
#   'video_lc': '28',
#   'video_vc': '169',
#   'video_cc': '9',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '8ZLMt_dCQyo',
#   'video_title': 'எங்க ஊரு ரவை தோசை recipe',
#   'video_pat': '2020-06-22T11:05:44Z',
#   'video_des': 'Tasty rava dosa recipe from our native',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 227,
#   'video_lc': '13',
#   'video_vc': '94',
#   'video_cc': '1',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'GJKLWNQpQBo',
#   'video_title': 'இந்த 11 steps-அ follow  பண்ணுங்க சுலபமான முறையில் நெய் தயார் பண்ணலாம்',
#   'video_pat': '2020-06-18T04:03:24Z',
#   'video_des': 'தெரிஞ்சிக்கலாம் வாங்க...\nHow to make ghee at home in easy way...\n#stayhomestaysafe\n#lockdownrecipes\n#cook\nTherinjikalam vaanga',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 255,
#   'video_lc': '13',
#   'video_vc': '113',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'pZ_37DzZqks',
#   'video_title': 'State uttu state.. Kerala chicken curry',
#   'video_pat': '2020-06-16T05:42:59Z',
#   'video_des': 'Spicy Kerala chicken curry\nIngredients\nFor marinating\nChicken 400g\nSalt to taste\nChilly powder 1tbspn\nCurd 3tspn\nLemon 1/2\nCorn flour 2tbspn\nGinger garlic paste 2tbspn\n\nFor gravy\nOnion 1\nTomato 2\nGreen chillies 2\nGinger garlic paste 1tspn\nChilly powder 1tspn\nGaram masala 1tspn\nCurd 3tspn\nSalt to taste',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 201,
#   'video_lc': '20',
#   'video_vc': '146',
#   'video_cc': '13',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'HMASM8ulax8',
#   'video_title': 'Tasty Chicken curry for chapati , rice and idiyappam',
#   'video_pat': '2020-06-13T13:35:58Z',
#   'video_des': 'How to make chicken curry',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 227,
#   'video_lc': '15',
#   'video_vc': '122',
#   'video_cc': '2',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'fCisjaYyOWY',
#   'video_title': 'மிஞ்சிய தோசை மாவுல சூப்பர் ஸ்நாக்ஸ் ரெடி |Super tasty snacks using leftover dosa batter',
#   'video_pat': '2020-06-10T01:54:18Z',
#   'video_des': '#உள்ளூர்சமையல்\n#ஸ்னாக்ஸ்\n#snacks\n#tiffan\n#easybreakfast',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 148,
#   'video_lc': '18',
#   'video_vc': '91',
#   'video_cc': '8',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '8Oi5hxCSMxc',
#   'video_title': 'Notification video...',
#   'video_pat': '2020-06-08T10:04:56Z',
#   'video_des': '',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 50,
#   'video_lc': '13',
#   'video_vc': '109',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'Tn16dYwwsd8',
#   'video_title': 'கேசரிய different a  சாப்பிடலாம் வாங்க',
#   'video_pat': '2020-06-06T14:11:35Z',
#   'video_des': 'Delicious sweet made with fruits',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 188,
#   'video_lc': '19',
#   'video_vc': '140',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'ieJwevFOdaE',
#   'video_title': 'Easy and quick different breakfast recipe | Potato pancake',
#   'video_pat': '2020-06-03T07:02:36Z',
#   'video_des': 'Make breakfast within 10 minutes\nIngredients\nPotatoes\nAll purpose flour\nMozorella cheese\nOnion\nCoriander leaves\nChilly powder\nSalt\nPepper\nOil for frying',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 173,
#   'video_lc': '21',
#   'video_vc': '149',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'EK8AUZx6N3c',
#   'video_title': 'கஷ்டம் இல்லைங்க இந்த ஸ்வீட் ரொம்ப ஈசி தாங்க.... வீட்டுலயே செய்யலாம்',
#   'video_pat': '2020-05-31T05:30:20Z',
#   'video_des': 'Like,Comment and Share....',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 183,
#   'video_lc': '24',
#   'video_vc': '166',
#   'video_cc': '8',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'M4jT2Xk4ZY0',
#   'video_title': 'Traditional eid sweets | Eid sweets | Eid special | Eid Mubarak',
#   'video_pat': '2020-05-23T09:49:39Z',
#   'video_des': '#eidsweets #eidspecial #eidmubarak #stayhomestaysafe\neidspecial\nSweets for biriyani\nhttps://youtu.be/agQ8yVt1l-s',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 383,
#   'video_lc': '31',
#   'video_vc': '271',
#   'video_cc': '14',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '8GaNCABuQoU',
#   'video_title': 'Ramadan Recipes...28 | பல விதமான வடிவங்களில் சமோசா செஞ்சி அசத்திடலாம் வாங்க',
#   'video_pat': '2020-05-22T05:02:49Z',
#   'video_des': 'How to different types of samosa in one dough and one stuffing...',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 401,
#   'video_lc': '20',
#   'video_vc': '165',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'n6bc2bLw0iM',
#   'video_title': 'Ramadan Recipe -27 | Banana Chocolate Balls | Kids Favourite',
#   'video_pat': '2020-05-20T23:42:14Z',
#   'video_des': 'Simple and Tasty recipe for iftar...',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 192,
#   'video_lc': '20',
#   'video_vc': '164',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'Ao9d6IGVA-Q',
#   'video_title': 'Ramadan Recipe... 26 | Snow  Pudding... | Kids Favourite',
#   'video_pat': '2020-05-19T23:28:55Z',
#   'video_des': 'How to make snow pudding...\n#iftarrecipe\n#ramadanrecipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 168,
#   'video_lc': '17',
#   'video_vc': '243',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'I3Q_CSvPRdY',
#   'video_title': 'Ramadan recipe - 25 | Watermelon pudding and Refreshing iftar juice',
#   'video_pat': '2020-05-19T01:04:24Z',
#   'video_des': '#ramadanrecipes #iftarrecipes #summerdrinks \nIngredients for watermelon pudding:\n\nWatermelon\nAgar agar\nWater \nSugar\n\nIngredients for watermelon juice:\nWatermelon\nCashews\nGinger\nGreen chilly\nSabja seeds\nSugar\nLemon',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 221,
#   'video_lc': '19',
#   'video_vc': '128',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'YNWTW1fyA_4',
#   'video_title': 'Ramadan Recipes -24 | Different aana Chicken Cutlet...',
#   'video_pat': '2020-05-18T04:40:21Z',
#   'video_des': 'How to make Macaroni chicken cutlet\n#ramadanrecipes\n#iftarsnacks',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 231,
#   'video_lc': '19',
#   'video_vc': '178',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'jsPL_WT1MeI',
#   'video_title': 'Ramadan Recipes -23 | இப்படி செஞ்சா சிக்கன் macaroni pasta சூப்பராக வரும்',
#   'video_pat': '2020-05-17T03:27:27Z',
#   'video_des': 'How to make perfect and tasty masala macaroni pasta...\n#ramadanrecipes\n#ramadantiffan\n#lockdownrecipes\n\n\nIngredients\ncloves\ncinnamon stick\ncardamom\nonion 2\ngreen chilli 1\ntomato 2\ncoriander\nmint\nchilli powder\nturmeric powder\nhomemade curry masala powder\nsalt \ntomato ketchup\nchicken\nmacaroni\nwater\n\n\nindian style macaroni pasta\nmasala pasta\nmacaroni pasta\nmasala macaroni pasta\nchicken masala macaroni pasta\nchicken macaroni',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 214,
#   'video_lc': '20',
#   'video_vc': '143',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'ITXAqfx-8sk',
#   'video_title': 'Ramadan recipe - 22 | Arabic sweet kunafa without oven',
#   'video_pat': '2020-05-16T01:12:11Z',
#   'video_des': '#ramadanrecipes #iftarrecipes #dessertrecipes \nArabic famous sweet kunafa without oven.\nArabic sweet kunafa is very popular among Arabs. Cheese lovers will love this kunafa very much.\n\nIngredients\nVermicelli\nButter\nCream cheese\nMozoralla cheese\nCondensed milk\nSugar\nHoney\nWater\nPistachios',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 274,
#   'video_lc': '34',
#   'video_vc': '332',
#   'video_cc': '9',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'LEf-zDnVLCs',
#   'video_title': 'Ramadan Recipes -21 | இடியாப்பம் பிரியாணி',
#   'video_pat': '2020-05-15T05:25:14Z',
#   'video_des': '#பிரியாணி\n#lockdownrecipes\n#ramadanrecipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 256,
#   'video_lc': '17',
#   'video_vc': '142',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'zR3bG3w9X4U',
#   'video_title': 'Ramadan Recipe -20 | உங்க family க்கு இந்த ஸ்வீட் செஞ்சி கொடுங்க...உங்கள பாராட்டமா இருக்க மாட்டாங்க',
#   'video_pat': '2020-05-13T23:19:43Z',
#   'video_des': '#ramadanrecipes\n#iftarsweets\n#lockdownsweets',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 165,
#   'video_lc': '29',
#   'video_vc': '171',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'yz1QKWEPxh0',
#   'video_title': 'Ramadan recipe - 19 | Healthy and yummy Milkshake',
#   'video_pat': '2020-05-13T00:49:43Z',
#   'video_des': '#ramadanrecipes #iftarrecipes #kidsfavoirite #lockdownrecipe\n\nIngredients\nBanana\nDates\nBadam\nJaggery\nMilk',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 114,
#   'video_lc': '17',
#   'video_vc': '186',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '5qFH8EhZWs8',
#   'video_title': 'Ramadan Recipe -18 | அருமையான வாழைப்பூ வடை',
#   'video_pat': '2020-05-12T00:03:00Z',
#   'video_des': 'வாழைப்பூ வடை செய்வது எப்படி',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 170,
#   'video_lc': '14',
#   'video_vc': '133',
#   'video_cc': '1',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'LqQHPHUqxYo',
#   'video_title': 'Ramadan Recipe -17 | Eid Special sheer khurma..',
#   'video_pat': '2020-05-11T02:48:05Z',
#   'video_des': 'How to make traditional sheer kuruma...\n#ramadanrecipes\n#iftarrecipes\n#iftarsnacks\n#sweetrecipes\n\n\nIngredients\nReduced from 1l to 750 ml Milk\nChopped cashew\nPeeled and Chopped badam\nChopped pista\nChopped dates\nkismis\n\nsemiya\n\nkesar\n Elakki powder\n\nsugar and condensed milk',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 199,
#   'video_lc': '24',
#   'video_vc': '211',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'M6SShIbnh1M',
#   'video_title': 'Ramadan recipe -16... Spring Roll',
#   'video_pat': '2020-05-10T05:47:33Z',
#   'video_des': 'How to make samosa sheet and spring roll',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 344,
#   'video_lc': '18',
#   'video_vc': '143',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'r7SUSXuYkAQ',
#   'video_title': 'Ramadan recipe - 15 | zebra pudding',
#   'video_pat': '2020-05-09T00:52:56Z',
#   'video_des': "#ramadanrecipes #iftarrecipes #lockdownsnacks #puddingrecipe\n\nIn this video we shows how to make zebra pudding without gelatin. Zebra pudding is very easy to make. Let's try this different zebra pudding",
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 215,
#   'video_lc': '28',
#   'video_vc': '327',
#   'video_cc': '8',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'J0XYpHWtinY',
#   'video_title': 'Ramadan Recipe -13 | Kids favourite chocolate lassi',
#   'video_pat': '2020-05-07T04:23:54Z',
#   'video_des': 'How to make chocolate lassi ...\n#stayhomestaysafe\n#iftarrecipes\n#ramadanrecipes\n\nIngredients:\nCurd 1 cup\nMilk   1/2 cup\nCoco Powder .. 1 spoon\nSugar.. 3 spoon\nChocolate syrup or melted chocolate',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 76,
#   'video_lc': '16',
#   'video_vc': '111',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'bZPtWstZn3c',
#   'video_title': 'Ramadan recipe 12 | காயல்பட்டினம் ஸ்பெஷல் வாடா | kayalpattinam special snacks வாடா',
#   'video_pat': '2020-05-06T00:56:49Z',
#   'video_des': '#ramadanrecipes #iftarrecipes #lockdownrecipe #snacks\n\nRice flour link\nhttps://youtu.be/OL7ILd9K1-o\n\nIngredients \nfor stuffing\nOil\nOnion\nMaasi powder\nSalt\nChilly powder\nCoconut..\n\nRice flour\nCoconut\nRice\nSalt\nChilly powder\nTurmeric powder',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 250,
#   'video_lc': '182',
#   'video_vc': '12931',
#   'video_cc': '13',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'l1EGiQBwDXA',
#   'video_title': 'Ramadan Recipes - 11 | நோன்பு கஞ்சி சுலபமாக செய்வது எப்படி | Veg Nonbu Kanchi',
#   'video_pat': '2020-05-04T23:27:22Z',
#   'video_des': 'How to prepare vegetable nonbu kanji in easy way...\n#iftarrecipes\n#ramadanrecipes\n#stayhomestaysafe\nIngredients\nRice\nMoong dal\nOnion\nTomato\nCarrot\nGreen chilly\nCoriander leaves\nJeera\nSalt\nOil\nCoconut milk',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 216,
#   'video_lc': '15',
#   'video_vc': '121',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'XS78cAmya2s',
#   'video_title': 'Ramadan recipe 10 | Crunchy potato sticks | Potato Cheese sticks',
#   'video_pat': '2020-05-04T00:47:07Z',
#   'video_des': '#ramadanrecipes #iftarrecipes #lockdownsnacks #snacksforkids\n\nIngredients\nPotatoes\nCorn starch\nMozorella cheese\nChilliflakes\nPepper\nSalt\nCoriander leaves\nOil for frying',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 188,
#   'video_lc': '33',
#   'video_vc': '256',
#   'video_cc': '10',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'TsgN7ZtxcXs',
#   'video_title': 'Ramadan Recipe -9 | Refreshing Iftar Juice | Watermelon Milk Chiller | Ramadan special',
#   'video_pat': '2020-05-02T23:13:08Z',
#   'video_des': 'How to make iftar refreshing juice\n#stayhomestaysafe\n#summerjuice\n#iftarrecipes\n#ramadanrecipes\nIngredients\nWatermelon\nMilk\nSugar\nNannaari syrup',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 83,
#   'video_lc': '27',
#   'video_vc': '231',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'NrgjhKZkcTg',
#   'video_title': 'Ramadan Recipe - 8 | Chicken pakoda | Chicken pakora |  சிக்கன் பக்கோடா | Crispy Chicken pakoda',
#   'video_pat': '2020-05-01T23:29:47Z',
#   'video_des': '#ramadanrecipes\n#ramzanrecipes\n#iftarsnacks\n#iftarrecipes\n#stayhomestaysafe\nHow to make chicken pakkoda in tamil\nLike,Comment and Share\nChicken recipes\n\nChicken..250 gm\nSalt..1  spoon\nChilli Powder...1 spoon\nTurmeric powder ... 1/2  spoon\nGaram masala podwer .... 1/2 spoon\nGinger Garlic paste 1 spoon\nLime juice...1 spoon\n\nGram flour...3 spoon\nRice Flour....1 spoon\nChilli flakes...1/2 spoon\nfennel powder...1 /2 spoon\negg...1\n\nOnion ...1\nGreen chilli...1\ncoriander\nginger...small piece\ncurry leaves',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 165,
#   'video_lc': '22',
#   'video_vc': '199',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'xTNyf9o1aGo',
#   'video_title': 'Ramadan recipe -7 | Ramadan super tiffan recipe...',
#   'video_pat': '2020-04-30T23:24:45Z',
#   'video_des': '#ramadanrecipe\n#iftarrecipe\n#tiffanrecipe',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 181,
#   'video_lc': '24',
#   'video_vc': '276',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '9H2z9b09Qvc',
#   'video_title': 'Ramadan Recipe -6 | ramadan zahar super side dish...Panneer tikka with green chutney',
#   'video_pat': '2020-04-30T03:17:53Z',
#   'video_des': 'How to make panneer tikka with green chutney\n...\nLike,Comment and Share...',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 220,
#   'video_lc': '23',
#   'video_vc': '131',
#   'video_cc': '11',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'xe08KDkvA7Q',
#   'video_title': 'Ramadan recipe-5 | pachai payaru vadai | பச்சை பயறு வடை | Healthy iftar snacks |green moong dal vada',
#   'video_pat': '2020-04-28T22:45:28Z',
#   'video_des': 'Ramada iftar recipe \nHow to make pacha payaru vadai... vadai recipe...\nLike,Comment and Share...\n\n#stayhomestaysafe\n#iftarrecipe\n#ramadaniftarrecipe\n#iftarsnacks\n#lockdownsnacks\n#stayhome cook #withme\n\nபச்சை பயறு 1 கப்\nசின்ன வெங்காயம் 5\nமிளகாய் 2\nஇஞ்சி சின்ன துண்டு\nசீரகம் 1/2 தேக்கரண்டி\nஉப்பு \nகொத்தமல்லி தழை',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 158,
#   'video_lc': '27',
#   'video_vc': '378',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'zcKkBGkGM5E',
#   'video_title': 'Ramadan recipe - 4 | உடலுக்கு ஆரோக்கியமான இந்த கஞ்சி செஞ்சி சாப்பிடுங்க | நோன்பு கஞ்சி | nonbu kanji',
#   'video_pat': '2020-04-28T01:20:28Z',
#   'video_des': '#ramadanrecipes #iftarrecipes\nHow to prepare ramadan nonbu kanji\nLike,Comment and Share\n\n#stayhomestaysafe\n#ramadanrecipe\n#ramadan',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 190,
#   'video_lc': '23',
#   'video_vc': '178',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'njfl-kAEEIs',
#   'video_title': 'Ramadan recipe 3 | இந்த முறையில் உருளைக்கிழங்கு போண்டா செய்து பாருங்கள் அட்டகாசமா வரும்....',
#   'video_pat': '2020-04-27T01:29:08Z',
#   'video_des': '#ramadanrecipes #lockdownsnacks #lockdown #snacks #stayhomestaysafe\nHow to make potato bonda in proper way...\nramadan iftar recipe  potato bonda...\nperfect tea kadai potato bonda\n...nonbu snacks...\nlockdown snacks\n\nஉருளைகிழங்கு போண்டா | Aloo Bonda in Tamil\n\nதேவையான பொருட்கள்\n\nஉருளைக்கிழங்கு மசாலா  செய்ய \n\nவேகவைத்த உருளைக்கிழங்கு - 3\nகடுகு  - 1/4 தேக்கரண்டி\nசீரகம் - 1/4 தேக்கரண்டி\nவெங்காயம் - 1 \nபச்சை மிளகாய் - 1\nஇஞ்சி பூண்டு\nபெருங்காயம் \nமஞ்சள் தூள் - 1/4 தேக்கரண்டி\nகொத்துமல்லி தழை\nஎண்ணெய்\nஉப்பு\n\nமாவு தயாரிக்க\n\nகடலை மாவு - 1 கப்\nஅரிசி மாவு - 1/4 கப்\nமிளகாய் தூள் - 1 தேக்கரண்டி\nமஞ்சள் தூள் - 1/4 தேக்கரண்டி\nபெருங்காயம்\nஆப்ப சோடா -1/4\nஉப்பு\nதண்ணீர்\nஎண்ணெய்',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 223,
#   'video_lc': '24',
#   'video_vc': '237',
#   'video_cc': '7',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'winrGyyJiuI',
#   'video_title': 'Ramadan recipe 2 | bread sweet roll',
#   'video_pat': '2020-04-25T23:28:50Z',
#   'video_des': 'Like,Comment and Share\n#stayhomestaysafe\n#ramadanrecipes\n#ramadan2020\n#lockdownsnacks\nbread sweet roll\nbread banana roll\nbread roll',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 228,
#   'video_lc': '35',
#   'video_vc': '307',
#   'video_cc': '8',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'c51tZWvjy2o',
#   'video_title': 'Ramadan recipe 1 |  ரமழான் நோன்பு கறி கஞ்சி | Nonbu kanji | நோன்பு கஞ்சி',
#   'video_pat': '2020-04-24T23:27:37Z',
#   'video_des': 'How to prepare ramadan nonbu kanji\nLike,Comment and Share\n\n#stayhomestaysafe\n#ramadanrecipe\n#ramadan',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 241,
#   'video_lc': '24',
#   'video_vc': '283',
#   'video_cc': '9',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '2f7gCHnOU-w',
#   'video_title': 'Lockdown snacks recipe  | kara sev',
#   'video_pat': '2020-04-24T05:17:47Z',
# ...
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'yYTs7Z8kTGI',
#   'video_title': 'Ramadan recipes.. Recipe 9 Momos',
#   'video_pat': '2019-05-15T06:22:29Z',
#   'video_des': '#iftar recipes\n#Ramadan recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 263,
#   'video_lc': '14',
#   'video_vc': '128',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '7VueVoRWeoo',
#   'video_title': 'Ramadan recipes.. Recipe 8 chicken வடை',
#   'video_pat': '2019-05-14T06:08:01Z',
#   'video_des': '#iftar recipes\n#ramadan recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 150,
#   'video_lc': '14',
#   'video_vc': '148',
#   'video_cc': '0',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'USROD5ZQ4iU',
#   'video_title': 'Ramadan recipes.. Recipe 7 Ceylon parotta',
#   'video_pat': '2019-05-13T06:53:36Z',
#   'video_des': '#iftar recipes\n#Ramadan recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 255,
#   'video_lc': '16',
#   'video_vc': '282',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'eleckDLGOp4',
#   'video_title': 'Ramadan recipes.. Recipe 6',
#   'video_pat': '2019-05-12T06:50:13Z',
#   'video_des': '#iftar recipes\n#ramadan recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 188,
#   'video_lc': '12',
#   'video_vc': '136',
#   'video_cc': '0',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'dZHL4iB_xaQ',
#   'video_title': 'Ramadan recipes.. Recipe 5 சுண்டல்',
#   'video_pat': '2019-05-11T05:35:39Z',
#   'video_des': '#iftar recipes\n#ramadan recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 140,
#   'video_lc': '14',
#   'video_vc': '97',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '0sHYgMptS4M',
#   'video_title': 'Ramadan recipes.. Recipe 4 chicken cheese balls',
#   'video_pat': '2019-05-10T05:56:32Z',
#   'video_des': '#iftar recipes\n#ramadan recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 191,
#   'video_lc': '19',
#   'video_vc': '179',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'IFxQ0rpeloE',
#   'video_title': 'Ramadan recipes.. Recipe 3 watermelon juice',
#   'video_pat': '2019-05-09T07:07:48Z',
#   'video_des': '#iftar recipes\n#ramadan recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 87,
#   'video_lc': '20',
#   'video_vc': '128',
#   'video_cc': '0',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'Z7mBra9vqeE',
#   'video_title': 'Ramadan recipes.. Recipe 2.. kaal paaya',
#   'video_pat': '2019-05-08T08:25:42Z',
#   'video_des': '#Ramadan recipes\n#iftar recipes\n#nonveg recipes\n#meat recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 257,
#   'video_lc': '20',
#   'video_vc': '193',
#   'video_cc': '2',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'sgXeFLrg6eY',
#   'video_title': 'Ramadan recipes.. Recipe 1.. Nonbu kanji',
#   'video_pat': '2019-05-07T06:29:31Z',
#   'video_des': 'Iftar recipes \n#Ramadan recipes\n#iftar recipes',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 194,
#   'video_lc': '20',
#   'video_vc': '138',
#   'video_cc': '1',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'lorFKWJXUf0',
#   'video_title': 'எப்போதும் இட்லி தோசை தானா இத ட்ரை பண்ணி பாருங்க',
#   'video_pat': '2019-05-06T09:44:04Z',
#   'video_des': 'Try this recipe for breakfast',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 151,
#   'video_lc': '12',
#   'video_vc': '98',
#   'video_cc': '0',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'FSU-2If91iw',
#   'video_title': 'இந்த combination ல டிபன் செஞ்சு பாருங்க',
#   'video_pat': '2019-05-05T03:13:53Z',
#   'video_des': 'Different breakfast recipe',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 151,
#   'video_lc': '14',
#   'video_vc': '98',
#   'video_cc': '0',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'E5CDjLiCO28',
#   'video_title': 'பூ போல் புட்டு  செய்வது எப்படி',
#   'video_pat': '2019-05-02T14:08:22Z',
#   'video_des': 'Soft puttu with delicious coconut milk',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 171,
#   'video_lc': '19',
#   'video_vc': '253',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '22349qOwAWI',
#   'video_title': 'இந்த மாதிரி கொழுக்கட்டை செஞ்சு பார்த்திருக்கீங்களா',
#   'video_pat': '2019-04-28T15:29:56Z',
#   'video_des': 'Sweet stuffed dumplings',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 159,
#   'video_lc': '16',
#   'video_vc': '142',
#   'video_cc': '2',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '52eQXW_RdWI',
#   'video_title': 'Tirunelveli traditional dish in tamil/how to make thakkadi',
#   'video_pat': '2019-04-25T14:59:55Z',
#   'video_des': 'Traditional south side special dish',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 456,
#   'video_lc': '92',
#   'video_vc': '4621',
#   'video_cc': '9',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'lBkh6I4JtOk',
#   'video_title': 'பல வகை குழம்புக்கு இந்த மசலாவை உபயோகிக்கலாம்',
#   'video_pat': '2019-04-23T06:38:52Z',
#   'video_des': 'Preparation of masala',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 94,
#   'video_lc': '15',
#   'video_vc': '109',
#   'video_cc': '2',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'ZtCXPZXzV-4',
#   'video_title': 'இதுதான் பால் கொழுக்கட்டையோட பாரம்பரிய செய்முறை',
#   'video_pat': '2019-04-19T02:44:27Z',
#   'video_des': 'Traditional recipe of cooking sweet dumplings',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 216,
#   'video_lc': '21',
#   'video_vc': '161',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'OL7ILd9K1-o',
#   'video_title': 'எங்க ஊரு பாரம்பரிய அரிசி மாவு வகைகள்',
#   'video_pat': '2019-04-16T08:53:09Z',
#   'video_des': 'Preparation of our traditional rice flour',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 559,
#   'video_lc': '44',
#   'video_vc': '822',
#   'video_cc': '11',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'jzOEeVexkwE',
#   'video_title': 'சிக்கன் முருங்கைக்காய் கிரேவி',
#   'video_pat': '2019-04-12T11:00:45Z',
#   'video_des': 'Chicken drumstick gravy',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 218,
#   'video_lc': '16',
#   'video_vc': '140',
#   'video_cc': '1',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '-_q-gt_2ft0',
#   'video_title': 'Traditional sweet..Easy and perfect egg pudding..வட்லப்பம்',
#   'video_pat': '2019-04-09T15:16:36Z',
#   'video_des': 'Delicious egg pudding',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 193,
#   'video_lc': '14',
#   'video_vc': '174',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'hSzYja_UPpg',
#   'video_title': 'Hariyali chicken',
#   'video_pat': '2019-04-05T19:09:41Z',
#   'video_des': 'Restaurant style hariyali chicken',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 250,
#   'video_lc': '17',
#   'video_vc': '92',
#   'video_cc': '1',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'aAyUr7dm-og',
#   'video_title': 'ரொம்ப ஈஸியான சிக்கன் கிரேவி',
#   'video_pat': '2019-04-02T09:44:22Z',
#   'video_des': 'Simple and different chicken recipe',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 202,
#   'video_lc': '18',
#   'video_vc': '104',
#   'video_cc': '2',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'cXS8KFxkkgY',
#   'video_title': 'மிளகு கறி இனி இப்படி செஞ்சு அசத்துங்க',
#   'video_pat': '2019-03-30T04:20:40Z',
#   'video_des': 'Spicy tasty pepper chicken',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 282,
#   'video_lc': '29',
#   'video_vc': '245',
#   'video_cc': '1',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '54jCeLqiPJo',
#   'video_title': 'வீட்ல லன்ச்கு திடீர்னு விருந்தாளி வந்துட்டாங்களா.. 10 நிமிஷம் போதும் இது செஞ்சு அசத்துங்க',
#   'video_pat': '2019-03-27T16:22:39Z',
#   'video_des': 'New style chicken recipe.. try this and comment us',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 206,
#   'video_lc': '26',
#   'video_vc': '239',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'tdMWoeTFIkI',
#   'video_title': 'ரவை ஸ்வீட்னாலே கேசரி மட்டும் தானா.. இத  செஞ்சு அசத்துங்க',
#   'video_pat': '2019-03-24T11:08:51Z',
#   'video_des': 'Delicious sweet using simple ingredients rava, milk, sugar, cashew and almond',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 162,
#   'video_lc': '31',
#   'video_vc': '143',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'y7Lzfc6b_T4',
#   'video_title': 'கடலைப்பருப்பு பாயாசம்',
#   'video_pat': '2019-03-21T16:55:38Z',
#   'video_des': 'Chana dal sweet.. try this and comment us\nIngredients:\nChana dal 1cup\nMoong dal 1/2 cup\nCoconut milk 1 cup\nJagger 1 cup\nGhee\nCashew, raisins, small piece of coconut',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 189,
#   'video_lc': '15',
#   'video_vc': '127',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'rcVY7E_lKhQ',
#   'video_title': 'வீட்ல சர்க்கரைல இருந்து எண்ணெய் வரை எல்லாத்தையும் மாத்தியாச்சு.. பாயாசம் மாத்தலனா எப்படி..',
#   'video_pat': '2019-03-20T10:43:40Z',
#   'video_des': 'ஆரோக்கியமான தினை பாயாசம்  செய்து பாருங்கள் ... try this different healthy and tasty sweet',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 199,
#   'video_lc': '15',
#   'video_vc': '165',
#   'video_cc': '2',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'kAFSwXETQ6k',
#   'video_title': 'சுரைக்காய் பாயாசம் ..',
#   'video_pat': '2019-03-18T10:06:35Z',
#   'video_des': 'Tasty and healthy bottle guard kheer.. try it and comment us',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 230,
#   'video_lc': '19',
#   'video_vc': '130',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'Bv_9anv4bF4',
#   'video_title': 'கேரட் கீர் :)',
#   'video_pat': '2019-03-16T12:29:10Z',
#   'video_des': 'Kids will love this carrot kheer for sure',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 161,
#   'video_lc': '22',
#   'video_vc': '155',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': '-EkWdAZru7g',
#   'video_title': 'இந்த பாயாசம் செஞ்சு பாருங்க சுவை அள்ளும்.. :)',
#   'video_pat': '2019-03-15T12:52:21Z',
#   'video_des': 'Try this healthy and yummy sweet.. :)',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'hd',
#   'video_duration': 195,
#   'video_lc': '25',
#   'video_vc': '374',
#   'video_cc': '6',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'aV4_sxh3pa8',
#   'video_title': 'தேங்காய் பால் எடுப்பது இவ்வளவு சுலபமா ..',
#   'video_pat': '2019-03-13T11:52:34Z',
#   'video_des': 'Easy way to take coconut milk',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 121,
#   'video_lc': '20',
#   'video_vc': '154',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 't7GJ22GHqQs',
#   'video_title': 'வீட்டில் உள்ளவங்களுக்கு வயிற்று  புண் இருக்கிறதா .. இத  செஞ்சு குடுங்க | ஜவ்வரிசி பாயாசம்',
#   'video_pat': '2019-03-12T11:36:10Z',
#   'video_des': 'Healthy and tasty sago seeds recipe..',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 165,
#   'video_lc': '24',
#   'video_vc': '220',
#   'video_cc': '5',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'gzP50pRyjIY',
#   'video_title': 'சுவையான கோசுமல்லி சட்னி',
#   'video_pat': '2019-03-10T13:25:12Z',
#   'video_des': 'Brinjal recipe for rice, idly, dosa',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 153,
#   'video_lc': '24',
#   'video_vc': '146',
#   'video_cc': '3',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'CVIBrcaurS4',
#   'video_title': 'எப்போதுமே தேங்காய் சட்னி தானா .. இத try பண்ணி பாருங்க',
#   'video_pat': '2019-03-08T11:08:06Z',
#   'video_des': 'Different chutney..\nIngredients:\nCoconut, Coriander leaves, Curry leaves, Mint leaves, Garlic, Green chilies, Tamarind, Salt',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 126,
#   'video_lc': '26',
#   'video_vc': '245',
#   'video_cc': '4',
#   'video_fc': '0'},
#  {'channel_id': 'UCWphTVXhpV6RTcQffM_NbxQ',
#   'channel_name': 'Engal Samayal எங்கள் சமையல்',
#   'video_id': 'nSdTnRo--Z8',
#   'video_title': 'துவையல் வகைகள் (chutneys)',
#   'video_pat': '2019-03-06T08:45:01Z',
#   'video_des': 'சுவையான துவையல் வகைகள் நொடியில்.. for rice, idly and dosa',
#   'video_tags': None,
#   'video_captionstatus': 'false',
#   'video_def': 'sd',
#   'video_duration': 155,
#   'video_lc': '36',
#   'video_vc': '919',
#   'video_cc': '9',
#   'video_fc': '0'}]

# %%
def get_comment_data(Video_Ids):
    comment_data = []
    try:
        for video_id in Video_Ids:
            request = youtube.commentThreads().list(
                                                    part="snippet",
                                                    videoId=video_id,
                                                    maxResults = 50
                                                    )
            response = request.execute()
            data2 = {"comment_id":response['items'][0]['id'],
                    "video_id":response['items'][0]['snippet']['videoId'],
                    "comment_text":response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay'],
                    "comment_author":response['items'][0]['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                    "comment_pat":response['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt']}
            comment_data.append(data2)
    except:
        pass
    return comment_data

# %%
comment_info = get_comment_data(video_Ids)

# %%
comment_info
# Out:
# [{'comment_id': 'UgwKL7POoM9jVGl22uJ4AaABAg',
#   'video_id': 'mpz317KgF68',
#   'comment_text': 'Superb 👌 Stay connected',
#   'comment_author': '@sk_organichealthykitchen6897',
#   'comment_pat': '2020-12-13T16:03:17Z'},
#  {'comment_id': 'Ugy8EVg1QFRrzQH9lnB4AaABAg',
#   'video_id': 'qulj2SaVpZc',
#   'comment_text': 'Yummy 👌',
#   'comment_author': '@sk_organichealthykitchen6897',
#   'comment_pat': '2020-11-30T14:56:14Z'},
#  {'comment_id': 'Ugxecrg1PYmHU4EiacV4AaABAg',
#   'video_id': 'v-DkWH2dbYI',
#   'comment_text': 'Ok . Thanku. Stay connected',
#   'comment_author': '@Easyfoodieworld86',
#   'comment_pat': '2020-09-19T16:02:44Z'},
#  {'comment_id': 'UgwidnPLrGMuAHFBnAR4AaABAg',
#   'video_id': 'BQrahU9HjQY',
#   'comment_text': 'Wow superb 👍 use full sharing sister',
#   'comment_author': '@puthamputhusamayal8360',
#   'comment_pat': '2021-01-21T11:02:00Z'},
#  {'comment_id': 'Ugx12OeVIISWoWBxxzF4AaABAg',
#   'video_id': 'mt6Z-ULhPGo',
#   'comment_text': 'Nice',
#   'comment_author': '@rafeekrazakamaaludheen1665',
#   'comment_pat': '2020-09-15T15:28:44Z'},
#  {'comment_id': 'UgwT-vhs6G2ja-lJI3N4AaABAg',
#   'video_id': '3egvhKLJMrQ',
#   'comment_text': 'Paakavae nalla iruku. Ella fish la yum pannalama? Or only particular fish?',
#   'comment_author': '@jarinabegum4675',
#   'comment_pat': '2020-09-13T09:59:06Z'},
#  {'comment_id': 'Ugz7AHduePasrrDfraF4AaABAg',
#   'video_id': 'i_uMa2LMBe8',
#   'comment_text': 'Super',
#   'comment_author': '@jarinabegum4675',
#   'comment_pat': '2020-09-10T09:40:59Z'},
#  {'comment_id': 'UgxSsOgPBunwDx4fCTJ4AaABAg',
#   'video_id': 'mv_d2ppkCqs',
#   'comment_text': 'Yemmy yana curd vadei super sis',
#   'comment_author': '@rasikibrahim6190',
#   'comment_pat': '2020-09-11T00:11:36Z'},
#  {'comment_id': 'Ugw0MsqX-YwaSjGpgpR4AaABAg',
#   'video_id': 'taVaHGtPs68',
#   'comment_text': 'Hi. I&#39;m new friend for you. <br>Please visit my home <br>Healthy briyani super...',
#   'comment_author': '@apc-lifestyle',
#   'comment_pat': '2020-09-07T13:23:20Z'},
#  {'comment_id': 'UgyDyQm9sVKPDHdx3cB4AaABAg',
#   'video_id': 'EzWIbWBMQhE',
#   'comment_text': 'Looks superb! yummy!!',
#   'comment_author': '@PriyaSamayal',
#   'comment_pat': '2020-09-06T09:34:26Z'},
#  {'comment_id': 'Ugw1T44k4ikzoMB2P8h4AaABAg',
#   'video_id': 'GSnD6LKmss0',
#   'comment_text': 'மாஷா அல்லாஹ் சூப்பர்',
#   'comment_author': '@mffaizal6536',
#   'comment_pat': '2021-08-31T19:50:17Z'},
#  {'comment_id': 'Ugws_FOxjwSZ55aDYC94AaABAg',
#   'video_id': 'iuPCQ0ERTGM',
#   'comment_text': 'Super',
#   'comment_author': '@sithirameeza4383',
#   'comment_pat': '2020-08-30T15:33:08Z'},
#  {'comment_id': 'UgwYjAqhNcEJswPQke54AaABAg',
#   'video_id': '18qsCLIu-p0',
#   'comment_text': 'Super',
#   'comment_author': '@k.a.regina8315',
#   'comment_pat': '2023-07-29T06:53:32Z'},
#  {'comment_id': 'UgznMpHz9sfXwiWK_d54AaABAg',
#   'video_id': 'vxOw3zKKXhQ',
#   'comment_text': 'Hi) Thanks for sharing your video! Looks very good !!! I am your subscriber! I would be glad if you visit my channel.  I wish you success and support!)',
#   'comment_author': '@olgam6299',
#   'comment_pat': '2020-08-26T17:43:15Z'},
#  {'comment_id': 'Ugycow5b0OaOAmM9MSd4AaABAg',
#   'video_id': '9ZARh4gt89M',
#   'comment_text': 'Easy wow',
#   'comment_author': '@nasrinfathima1589',
#   'comment_pat': '2020-08-25T08:12:15Z'},
#  {'comment_id': 'Ugy_QLRZnhs-onEkqvh4AaABAg',
#   'video_id': 'bNnf3mwhnzM',
#   'comment_text': 'Useful recipe sollirukinga i will try',
#   'comment_author': '@rafeekrazakamaaludheen1665',
#   'comment_pat': '2020-08-22T12:10:48Z'}]

# %%
import pandas as pd

# %%
def create_channel_dataframe(channel_id):
    channel_data = get_channel_data(channel_id)
    df_channel = pd.DataFrame([channel_data])
    
    return df_channel

# %%
Df_channel = create_channel_dataframe("UCWphTVXhpV6RTcQffM_NbxQ")

# %%
Df_channel['channel_name']
# Out:
# 0    Engal Samayal எங்கள் சமையல்
# Name: channel_name, dtype: object

# %%
all_channels = []

# %%
def create_video_dataframe(channel_id):
    video_data = get_video_data(get_video_ids(channel_id))
    df_video = pd.DataFrame.from_dict(video_data)
    return df_video

# %%
def create_comment_dataframe(channel_id):
    comment_data = get_comment_data(get_video_ids(channel_id))
    df_comment = pd.DataFrame.from_dict(comment_data)
    return df_comment

# %%
channel_data=get_channel_data("UCWphTVXhpV6RTcQffM_NbxQ")

# %%
df_channel = pd.DataFrame([channel_data])

# %%
df_channel
# Out:
#                   channel_name  \
# 0  Engal Samayal எங்கள் சமையல்
#
#                                          channel_des  \
# 0  "Traditional, healthy and tasty south tamilnad...
#
#                channel_p_id          channel_pat channel_sub_count  \
# 0  UUWphTVXhpV6RTcQffM_NbxQ  2019-03-06 08:32:53              1150
#
#   channel_vcount channel_vid_count                channel_id
# 0         132545               218  UCWphTVXhpV6RTcQffM_NbxQ

# %%
# !pip install mysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.0.3)
# Requirement already satisfied: mysqlclient in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mysql) (2.2.4)

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector-python in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (8.3.0)

# %%
import mysql.connector

# %%
client = mysql.connector.connect(host = "localhost",
                                 user = "root",
                                 password = "Farshi@25",
                                 )
client

# %%
cursor = client.cursor()

# %%
query = "create database Project_1"
cursor.execute(query)

# %%
def channels_table():
    client = mysql.connector.connect(host = "localhost",
                                    user = "root",
                                    password = "Zahil@2020",
                                    database = "Youtube_Data")
    cursor = client.cursor()

    query = """create table if not exists channel_details(channel_name varchar(255),
                                            channel_des text,
                                            channel_p_id varchar(255),
                                            channel_pat timestamp,
                                            channel_sub_count bigint,
                                            channel_vcount bigint,
                                            channel_vid_count bigint,
                                            channel_id varchar(255) primary key
                                            )"""
    cursor.execute(query)
    client.commit()

    query = """insert into channel_details values(%s,%s,%s,%s,%s,%s,%s,%s)"""
    values = [tuple(row) for row in create_channel_dataframe(channel_id).values]
    cursor.executemany(query,values)
    client.commit()

# %%
def videos_table():

    client = mysql.connector.connect(host = "localhost",
                                    user = "root",
                                    password = "Zahil@2020",
                                    database = "Youtube_Data")
    cursor = client.cursor()

    query = """create table if not exists video_details(channel_id varchar(255),
                                                        channel_name varchar(255),
                                                        video_id varchar(255) primary key,
                                                        video_title varchar(255),
                                                        video_pat varchar(100),
                                                        video_des text,
                                                        video_tags text,
                                                        video_captionstatus varchar(255),
                                                        video_def varchar(255),
                                                        video_duration varchar(10),
                                                        video_lc bigint,
                                                        video_vc bigint,
                                                        video_cc bigint,
                                                        video_fc int,
                                                        Foreign key (channel_id) references channel_details(channel_id)
                                                        )"""
    cursor.execute(query)
    client.commit()

    query = """insert into video_details values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
    values = [tuple(row) for row in df_video.values]
    cursor.executemany(query,values)
    client.commit()

# %%
query = """insert into video_details values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
values = [tuple(row) for row in df_video.values]

cursor.executemany(query,values)
client.commit()

# %%
def comments_table():

    client = mysql.connector.connect(host = "localhost",
                                    user = "root",
                                    password = "Zahil@2020",
                                    database = "Youtube_Data")
    cursor = client.cursor()

    query = """create table if not exists comment_details(comment_id varchar(255),
                                                        video_id varchar(255) ,
                                                        comment_text text,
                                                        comment_author varchar(255),
                                                        comment_pat varchar(255),
                                                        Foreign key (video_id) references video_details(video_id))"""
    cursor.execute(query)
    client.commit()

    query = """insert into comment_details values(%s,%s,%s,%s,%s)"""
    values = [tuple(row) for row in df_comment.values]
    cursor.executemany(query,values)
    client.commit()

# %%
query = "ALTER TABLE comment_details MODIFY comment_pat varchar(100)"
cursor.execute(query)

# %%
query = """insert into comment_details values(%s,%s,%s,%s,%s)"""
values = [tuple(row) for row in df_comment.values]

cursor.executemany(query,values)
client.commit()

# %%
df_comment= pd.DataFrame.from_dict(comment_info)

# %%
df_comment
# Out:
#                     comment_id     video_id  \
# 0   UgwKL7POoM9jVGl22uJ4AaABAg  mpz317KgF68
# 1   Ugy8EVg1QFRrzQH9lnB4AaABAg  qulj2SaVpZc
# 2   Ugxecrg1PYmHU4EiacV4AaABAg  v-DkWH2dbYI
# 3   UgwidnPLrGMuAHFBnAR4AaABAg  BQrahU9HjQY
# 4   Ugx12OeVIISWoWBxxzF4AaABAg  mt6Z-ULhPGo
# 5   UgwT-vhs6G2ja-lJI3N4AaABAg  3egvhKLJMrQ
# 6   Ugz7AHduePasrrDfraF4AaABAg  i_uMa2LMBe8
# 7   UgxSsOgPBunwDx4fCTJ4AaABAg  mv_d2ppkCqs
# 8   Ugw0MsqX-YwaSjGpgpR4AaABAg  taVaHGtPs68
# 9   UgyDyQm9sVKPDHdx3cB4AaABAg  EzWIbWBMQhE
# 10  Ugw1T44k4ikzoMB2P8h4AaABAg  GSnD6LKmss0
# 11  Ugws_FOxjwSZ55aDYC94AaABAg  iuPCQ0ERTGM
# 12  UgwYjAqhNcEJswPQke54AaABAg  18qsCLIu-p0
# 13  UgznMpHz9sfXwiWK_d54AaABAg  vxOw3zKKXhQ
# 14  Ugycow5b0OaOAmM9MSd4AaABAg  9ZARh4gt89M
# 15  Ugy_QLRZnhs-onEkqvh4AaABAg  bNnf3mwhnzM
#
#                                          comment_text  \
# 0                             Superb 👌 Stay connected
# 1                                             Yummy 👌
# 2                         Ok . Thanku. Stay connected
# 3                Wow superb 👍 use full sharing sister
# 4                                                Nice
# 5   Paakavae nalla iruku. Ella fish la yum pannala...
# 6                                               Super
# 7                     Yemmy yana curd vadei super sis
# 8   Hi. I&#39;m new friend for you. <br>Please vis...
# 9                               Looks superb! yummy!!
# 10                               மாஷா அல்லாஹ் சூப்பர்
# 11                                              Super
# 12                                              Super
# 13  Hi) Thanks for sharing your video! Looks very ...
# 14                                           Easy wow
# 15              Useful recipe sollirukinga i will try
#
#                    comment_author           comment_pat
# 0   @sk_organichealthykitchen6897  2020-12-13T16:03:17Z
# 1   @sk_organichealthykitchen6897  2020-11-30T14:56:14Z
# 2              @Easyfoodieworld86  2020-09-19T16:02:44Z
# 3         @puthamputhusamayal8360  2021-01-21T11:02:00Z
# 4     @rafeekrazakamaaludheen1665  2020-09-15T15:28:44Z
# 5                @jarinabegum4675  2020-09-13T09:59:06Z
# 6                @jarinabegum4675  2020-09-10T09:40:59Z
# 7               @rasikibrahim6190  2020-09-11T00:11:36Z
# 8                  @apc-lifestyle  2020-09-07T13:23:20Z
# 9                   @PriyaSamayal  2020-09-06T09:34:26Z
# 10                  @mffaizal6536  2021-08-31T19:50:17Z
# 11              @sithirameeza4383  2020-08-30T15:33:08Z
# 12                @k.a.regina8315  2023-07-29T06:53:32Z
# 13                     @olgam6299  2020-08-26T17:43:15Z
# 14             @nasrinfathima1589  2020-08-25T08:12:15Z
# 15    @rafeekrazakamaaludheen1665  2020-08-22T12:10:48Z

# %%
df_video = pd.DataFrame.from_dict(video_info)

# %%
df_video
# Out:
#                    channel_id                 channel_name     video_id  \
# 0    UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  mpz317KgF68
# 1    UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  qulj2SaVpZc
# 2    UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  v-DkWH2dbYI
# 3    UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  BQrahU9HjQY
# 4    UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  mt6Z-ULhPGo
# ..                        ...                          ...          ...
# 215  UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  aV4_sxh3pa8
# 216  UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  t7GJ22GHqQs
# 217  UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  gzP50pRyjIY
# 218  UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  CVIBrcaurS4
# 219  UCWphTVXhpV6RTcQffM_NbxQ  Engal Samayal எங்கள் சமையல்  nSdTnRo--Z8
#
#                                            video_title             video_pat  \
# 0        பால் மட்டும் போதும் இரண்டு ஸ்வீட் செஞ்சிடலாம்  2020-09-25T08:00:43Z
# 1    உங்க பசங்களுக்கு இந்த dish a செஞ்சிகுடுங்க | K...  2020-09-20T08:57:38Z
# 2    For Construction, Interiors,2D plan,3D Elevati...  2020-09-19T09:21:16Z
# 3                               Homemade Sambar powder  2020-09-18T03:56:54Z
# 4    காரமா சாப்பிடுறவங்க கண்டிப்பா இந்த dish a  செஞ...  2020-09-15T05:01:51Z
# ..                                                 ...                   ...
# 215           தேங்காய் பால் எடுப்பது இவ்வளவு சுலபமா ..  2019-03-13T11:52:34Z
# 216  வீட்டில் உள்ளவங்களுக்கு வயிற்று  புண் இருக்கிற...  2019-03-12T11:36:10Z
# 217                            சுவையான கோசுமல்லி சட்னி  2019-03-10T13:25:12Z
# 218  எப்போதுமே தேங்காய் சட்னி தானா .. இத try பண்ணி ...  2019-03-08T11:08:06Z
# 219                          துவையல் வகைகள் (chutneys)  2019-03-06T08:45:01Z
#
#                                              video_des video_tags  \
# 0    How to make sweets for this diwali\nhomemade s...       None
# 1        chocolate recipe\n\nchocolate custard pudding       None
# 2    At K.T.C nagar, Tirunelveli\n\n\nFacebook page...       None
# 3    Homemade Sambar powder. we can make Sambar pow...       None
# 4    Hyderabad chicken sukka...\n\nசமைக்கும் போது m...       None
# ..                                                 ...        ...
# 215                      Easy way to take coconut milk       None
# 216              Healthy and tasty sago seeds recipe..       None
# 217                Brinjal recipe for rice, idly, dosa       None
# 218  Different chutney..\nIngredients:\nCoconut, Co...       None
# 219  சுவையான துவையல் வகைகள் நொடியில்.. for rice, id...       None
#
#     video_captionstatus video_def video_duration video_lc video_vc video_cc  \
# 0                 false        hd            250       17      256        6
# 1                 false        hd            201       21      189        3
# 2                 false        hd             32       11      137        1
# 3                 false        hd            170       13      136        3
# 4                 false        hd            183       16      136        5
# ..                  ...       ...            ...      ...      ...      ...
# 215               false        sd            121       20      154        3
# 216               false        sd            165       24      220        5
# 217               false        sd            153       24      146        3
# 218               false        sd            126       26      245        4
# 219               false        sd            155       36      919        9
#
#     video_fc
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 215        0
# 216        0
# 217        0
# 218        0
# 219        0
#
# [220 rows x 14 columns]

# %%
def channel_details(channel_id):
   ch_details = get_channel_data(channel_id) 
   vi_ids = get_video_ids(channel_id)
   vi_details = get_video_data(vi_ids)
   com_details = get_comment_data(vi_ids)
   data = {'channel_info':ch_details, 'video_info':vi_details, 'comment_info':com_details}
   pd.DataFrame.from_dict(data)

   return "upload completed successfully"

# %%
def tables():
    channels_table()
    videos_table()
    comments_table()

    return "Tables created successfully"

# %%
Tables = tables()

# %%
Tables
# Out:
# 'Tables created successfully'

# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.34.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.8.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from streamlit) (5.3.3)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=16.8 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from streamlit) (24.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from streamlit) (2.2.2)
# Collecting pillow<11,>=7.1.0 (from streamlit)
#   Downloading pillow-10.3.0-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from streamlit) (4.25.3)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-16.0.0-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from streamlit) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions<5,>=4.3.0 (from streamlit)
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from streamlit) (6.4)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.0-py3-none-win_amd64.whl.metadata (37 kB)
# Collecting jinja2 (from altair<6,>=4.0->streamlit)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit)
#   Downloading jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: colorama in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.27->streamlit) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->altair<6,>=4.0->streamlit)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading rpds_py-0.18.0-cp312-none-win_amd64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\abdul\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading streamlit-1.34.0-py2.py3-none-any.whl (8.5 MB)
#    ---------------------------------------- 0.0/8.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.5 MB 5.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/8.5 MB 3.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/8.5 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/8.5 MB 3.6 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/8.5 MB 3.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/8.5 MB 3.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/8.5 MB 3.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.2/8.5 MB 3.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.4/8.5 MB 3.5 MB/s eta 0:00:03
#    ------- -------------------------------- 1.5/8.5 MB 3.3 MB/s eta 0:00:03
#    -------- ------------------------------- 1.7/8.5 MB 3.4 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.5 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 1.9/8.5 MB 3.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/8.5 MB 3.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.1/8.5 MB 3.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.3/8.5 MB 3.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.5 MB 3.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.5/8.5 MB 3.1 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.5 MB 3.1 MB/s eta 0:00:02
#    ------------- -------------------------- 2.8/8.5 MB 3.0 MB/s eta 0:00:02
#    ------------- -------------------------- 2.9/8.5 MB 3.0 MB/s eta 0:00:02
#    -------------- ------------------------- 3.0/8.5 MB 2.9 MB/s eta 0:00:02
#    -------------- ------------------------- 3.2/8.5 MB 3.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.3/8.5 MB 3.0 MB/s eta 0:00:02
 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp312-none-win_amd64.whl (206 kB)
#    ---------------------------------------- 0.0/206.3 kB ? eta -:--:--
#    --------------- ------------------------ 81.9/206.3 kB 2.3 MB/s eta 0:00:01
#    --------------------------- ------------ 143.4/206.3 kB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 194.6/206.3 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 206.3/206.3 kB 1.3 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, typing-extensions, toolz, toml, tenacity, smmap, rpds-py, pyarrow, pillow, mdurl, MarkupSafe, click, blinker, attrs, referencing, markdown-it-py, jinja2, gitdb, rich, pydeck, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed MarkupSafe-2.1.5 altair-5.3.0 attrs-23.2.0 blinker-1.8.1 click-8.1.7 gitdb-4.0.11 gitpython-3.1.43 jinja2-3.1.3 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 markdown-it-py-3.0.0 mdurl-0.1.2 pillow-10.3.0 pyarrow-16.0.0 pydeck-0.9.0 referencing-0.35.1 rich-13.7.1 rpds-py-0.18.0 smmap-5.0.1 streamlit-1.34.0 tenacity-8.2.3 toml-0.10.2 toolz-0.12.1 typing-extensions-4.11.0 watchdog-4.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

# %%
def show_channels_table():
    df1 = st.dataframe(df_channel)
    return df1

# %%
def show_videos_table():
    df2 = st.dataframe(df_video)
    return df2

# %%
def show_comments_table():
    df3 = st.dataframe(df_comment)
    return df3

# %%
with st.sidebar:
    st.title(":blue[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("Scrap")
    st.header("Insert")

channel_id = st.text_input("Enter the channel ID: ")

if st.button("collect and store data"):
    insert = channel_details(channel_id)
    st.success(insert)   

if st.button("Migrate to SQL"):
    Table = tables()
    st.success(Table)

show_table = st.radio("Select the table for view",("CHANNELS","VIDEOS","COMMENTS"))

if show_table == "CHANNELS":
    show_channels_table()

elif show_table == "VIDEOS":
    show_videos_table()

elif show_table == "COMMENTS":
    show_comments_table()

# %%
client = mysql.connector.connect(host = "localhost",
                                    user = "root",
                                    password = "Zahil@2020",
                                    database = "Youtube_Data")
cursor = client.cursor()

Questions = st.selectbox("Select your question",("1. What are the names of all the videos and their corresponding channels?",
                                                 "2. Which channels have the most number of videos, and how many videos do they have?",
                                                 "3. What are the top 10 most viewed videos and their respective channels?",
                                                 "4. How many comments were made on each video, and what are their corresponding video names?",
                                                 "5. Which videos have the highest number of likes, and what are their corresponding channel names?",
                                                 "6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?",
                                                 "7. What is the total number of views for each channel, and what are their corresponding channel names?",
                                                 "8. What are the names of all the channels that have published videos in the year 2022?",
                                                 "9. What is the average duration of all videos in each channel, and what are their corresponding channel names?",
                                                 "10. Which videos have the highest number of comments, and what are their corresponding channel names?"))
